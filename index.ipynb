# %% [markdown]
# # Recommendation Systems - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and attempt to build a recommendation system for a real world dataset! For this exercise, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# You will be able to:
# * Implement a recommendation system on a real world dataset

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd

df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %%
import networkx as nx
G = nx.Graph()

# %% [markdown]
# ## Load the MetaData

# %%
meta = pd.read_csv('books_meta.txt', sep='\t')
meta.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
OUT = meta[meta.Title.str.contains('Outlander')]
OUT
# Out:
#             Id        ASIN                                              Title  \
# 20818    29253  0385302304                                          Outlander
# 27984    39303  0373638329                           Outlanders: Tomb of Time
# 51498    71930  0373638388                    Talon and Fang (Outlanders #25)
# 96160   133941  0812571134   The Outlanders (The Lon Tobyn Chronicle, Book 2)
# 100066  139465  1569715149  Outlander - The Exile of Sharad Hett (Star War...
# 132013  184167  0373638299                      Tigers Of Heaven (Outlanders)
# 132990  185498  0440212561                                          Outlander
# 147989  206360  0553473298                                          Outlander
# 155271  216627  0553714538                                          Outlander
# 231703  321778  0373638280                     Doom Dynasty (Outlanders # 15)
# 235936  327533  0373638264   Shadow Scourge (Outlanders #13) (Outlanders, 13)
# 243823  338227  0385319959                                          Outlander
# 251403  348510  0373638302                         Outlanders: Purgatory Road
# 268410  371629  0373638337                       Outlanders: Prodigal Chalice
# 303510  419353  0373638310                       Outlanders: Sargasso Plunder
# 338877  467450  037363837X                      Equinox Zero (Outlanders #24)
# 356864  491957  0373638345                      Outlanders: Devil in the Moon
# 388221  535597  0373638361                        Far Empire (Outlanders #23)
# 389382  537372  0373638353                         Dragoneye (Outlanders #22)
#
#                                                Categories Group  SalesRank  \
# 20818   general travel subject author z gabaldon g his...  Book      65326
# 27984   adventur general subject literatur fantasi boo...  Book     730193
# 51498   adventur general subject literatur action fant...  Book     570026
# 96160            subject epic fantasi book scienc fiction  Book     112505
# 100066  literatur popular book graphic fiction subject...  Book      25245
# 132013  adventur general subject fantasi book scienc f...  Book     625820
# 132990  general travel subject author z paperback gaba...  Book       1596
# 147989  general travel subject literatur format author...  Book     233840
# 155271  general subject literatur diana author cd z ga...  Book     157609
# 231703  adventur general subject literatur action fant...  Book     696835
# 235936   adventur subject literatur book men genr fiction  Book     524533
# 243823  general subject author z paperback gabaldon hi...  Book      11336
# 251403  adventur general subject literatur fantasi boo...  Book     676815
# 268410  adventur subject literatur fantasi book scienc...  Book     735346
# 303510  adventur general subject literatur action fant...  Book     460464
# 338877  adventur general subject literatur action fant...  Book     609136
# 356864  adventur general subject literatur fantasi boo...  Book     648767
# 388221  adventur general subject literatur action fant...  Book     603533
# 389382  adventur general subject literatur action fant...  Book     606880
#
#         TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 20818           1015        4.5                 5             0.90
# 27984              9        5.0                 0             0.00
# 51498             10        5.0                 1             0.00
# 96160             16        4.0                 3             0.58
# 100066             6        4.5                 5             0.84
# 132013            11        5.0                 2             1.00
# 132990          1015        4.5                19             0.78
# 147989          1015        4.5                 5             0.90
# 155271          1015        4.5                 5             0.90
# 231703             7        5.0                 2             1.00
# 235936             6        5.0                 0             0.00
# 243823          1013        4.5                 5             0.90
# 251403             8        4.5                 0             0.00
# 268410             7        3.5                 0             0.00
# 303510             5        2.5                 0             0.00
# 338877            10        5.0                 0             0.00
# 356864            13        5.0                 0             0.00
# 388221             8        5.0                 0             0.00
# 389382            11        4.5                 3             0.58

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The 'books_data.edgelist' has conveniently already calculated the distance between items for you. Given this preprocessed and data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
rec_dict = {}
id_name_dict = dict(zip(meta.ASIN, meta.Title))
for row in OUT.index:
    book_id = OUT.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = df[(df.source==book_id) | (df.target==book_id)].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    recommendations = []
    for row in most_similar.index:
        if most_similar.source[row] == book_id:
            recommendations.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recommendations.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recommendations
    print("Recommendations for:", book_name)
    for r in recommendations:
        print(r)
    print('\n\n')
# Out:
# Recommendations for: Outlander
# ('Dragonfly in Amber', 0.86)
# ('Voyager', 0.86)
# ('Drums of Autumn', 0.71)
# ('The Fiery Cross', 0.59)
# ('Lord John and the Private Matter', 0.17)
#
#
#
# Recommendations for: Outlanders: Tomb of Time
#
#
#
# Recommendations for: Talon and Fang (Outlanders #25)
# ('Dragoneye (Outlanders #22)', 0.91)
#
#
#
# Recommendations for: The Outlanders (The Lon Tobyn Chronicle, Book 2)
# ('Rules of Ascension (Winds of the Forelands, Book 1)', 0.86)
# ('Children of Amarid (The Lon Tobyn Chronicle, Book 1)', 0.86)
# ('Seeds of Betrayal: Book 2 of the Winds of the Forelands Tetralogy', 0.86)
#
#
#
# Recommendations for: Outlander - The Exile of Sharad Hett (Star Wars: Ongoing, Volume 2)
# ('Star Wars - Jedi Council: Acts of War', 1.0)
# ('Emissaries to Malastare (Star Wars: Ongoing, Volume 3)', 1.0)
# ('Star Wars: The Hunt for Aurra Sing', 0.85)
# ('Twilight (Star Wars: Ongoing, Volume 4)', 0.85)
# ('Star Wars: Darkness', 0.46)
#
#
#
# Recommendations for: Tigers Of Heaven (Outlanders)
# ('Doom Dynasty (Outlanders # 15)', 0.64)
# ('Dragoneye (Outlanders #22)', 0.64)
#
#
#
# Recommendations for: Outlander
# ('Dragonfly in Amber', 1.0)
# ('Voyager', 1.0)
# ('Drums of Autumn', 0.85)
# ('Drums of Autumn', 0.85)
# ('Drums of Autumn', 0.71)
# ('Voyager', 0.71)
# ('The Fiery Cross', 0.69)
# ('Voyager', 0.62)
# ('The Fiery Cross', 0.59)
# ('Drums of Autumn', 0.59)
#
#
#
# Recommendations for: Outlander
# ('The Fiery Cross', 0.57)
# ('Dragonfly in Amber', 0.52)
# ('Voyager', 0.52)
# ('Drums of Autumn', 0.5)
# ('Lord John and the Private Matter', 0.23)
#
#
#
# Recommendations for: Outlander
# ('The Fiery Cross', 0.71)
# ('Drums of Autumn', 0.62)
# ('Dragonfly in Amber', 0.56)
# ('Voyager', 0.56)
# ('Lord John and the Private Matter', 0.28)
#
#
#
# Recommendations for: Doom Dynasty (Outlanders # 15)
# ('Dragoneye (Outlanders #22)', 1.0)
# ('Tigers Of Heaven (Outlanders)', 0.64)
#
#
#
# Recommendations for: Shadow Scourge (Outlanders #13) (Outlanders, 13)
#
#
#
# Recommendations for: Outlander
# ('Drums of Autumn', 1.0)
# ('Dragonfly in Amber', 0.85)
# ('Voyager', 0.85)
# ('The Fiery Cross', 0.79)
# ('Lord John and the Private Matter', 0.19)
#
#
#
# Recommendations for: Outlanders: Purgatory Road
#
#
#
# Recommendations for: Outlanders: Prodigal Chalice
#
#
#
# Recommendations for: Outlanders: Sargasso Plunder
#
#
#
# Recommendations for: Equinox Zero (Outlanders #24)
#
#
#
# Recommendations for: Outlanders: Devil in the Moon
#
#
#
# Recommendations for: Far Empire (Outlanders #23)
#
#
#
# Recommendations for: Dragoneye (Outlanders #22)
# ('Doom Dynasty (Outlanders # 15)', 1.0)
# ('Talon and Fang (Outlanders #25)', 0.91)
# ('Tigers Of Heaven (Outlanders)', 0.64)

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
